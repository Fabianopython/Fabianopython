# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabianopython/Fabianopython/blob/main/Modelos_de_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
# !pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Exemplo de dados para todos os gráficos
x = [1, 2, 3, 4, 5]
y = [5, 7, 8, 7, 6]
data = [1, 2, 2, 3, 3, 3, 4, 4, 5]
heatmap_data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# Gráfico de Dispersão
plt.figure(figsize=(10, 6))
plt.scatter(x, y)
plt.title('Gráfico de Dispersão')
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.show()

# %%
# Histograma
plt.figure(figsize=(10, 6))
plt.hist(data, bins=5)
plt.title('Histograma')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# %%
# Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title('Boxplot')
plt.show()

# %%
# Violin Plot
plt.figure(figsize=(10, 6))
sns.violinplot(data=data)
plt.title('Violin Plot')
plt.show()

# %%
# Swarmplot
plt.figure(figsize=(10, 6))
sns.swarmplot(data=data)
plt.title('Swarmplot')
plt.show()

# %%
# Mapa de Calor
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True)
plt.title('Mapa de Calor')
plt.show()
